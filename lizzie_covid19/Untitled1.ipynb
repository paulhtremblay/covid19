# %%
import pandas as pd
df = pd.read_csv('/home/lizhi/projects/covid19/rural_urban_codes_2013.csv')

# %%
import numpy as np

from bokeh.io import curdoc, show
from bokeh.models import ColumnDataSource, Grid, LinearAxis, Plot, Quad

N = 9
x = np.linspace(-2, 2, N)
y = x**2

source = ColumnDataSource(dict(
        left=x,
        top=y,
        right=x-x**3/10 + 0.3,
        bottom=y-x**2/10 + 0.5,
    )
)

plot = Plot(
    title=None, plot_width=300, plot_height=300,
    min_border=0, toolbar_location=None)

glyph = Quad(left="left", right="right", top="top", bottom="bottom", fill_color="#b3de69")
plot.add_glyph(source, glyph)

xaxis = LinearAxis()
plot.add_layout(xaxis, 'below')

yaxis = LinearAxis()
plot.add_layout(yaxis, 'left')

plot.add_layout(Grid(dimension=0, ticker=xaxis.ticker))
plot.add_layout(Grid(dimension=1, ticker=yaxis.ticker))

curdoc().add_root(plot)

show(plot)

# %%
df
# Out:
#        FIPS State          County_Name  Population_2010  RUCC_2013  \
# 0      1001    AL       Autauga County            54571          2
# 1      1003    AL       Baldwin County           182265          3
# 2      1005    AL       Barbour County            27457          6
# 3      1007    AL          Bibb County            22915          1
# 4      1009    AL        Blount County            57322          1
# ...     ...   ...                  ...              ...        ...
# 3216  72145    PR  Vega Baja Municipio            59662          1
# 3217  72147    PR    Vieques Municipio             9301          7
# 3218  72149    PR   Villalba Municipio            26073          2
# 3219  72151    PR    Yabucoa Municipio            37941          1
# 3220  72153    PR      Yauco Municipio            42043          2
#
#                                             Description  \
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# 2     Nonmetro - Urban population of 2,500 to 19,999...
# 3     Metro - Counties in metro areas of 1 million p...
# 4     Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3216  Metro - Counties in metro areas of 1 million p...
# 3217  Nonmetro - Urban population of 2,500 to 19,999...
# 3218  Metro - Counties in metro areas of 250,000 to ...
# 3219  Metro - Counties in metro areas of 1 million p...
# 3220  Metro - Counties in metro areas of 250,000 to ...
#
#       orignal_population_2010_wa
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3216                         NaN
# 3217                         NaN
# 3218                         NaN
# 3219                         NaN
# 3220                         NaN
#
# [3221 rows x 7 columns]

# %%
df.shape
# Out:
# (3221, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FIPS                        3221 non-null   int64
#  1   State                       3221 non-null   object
#  2   County_Name                 3221 non-null   object
#  3   Population_2010             3221 non-null   int64
#  4   RUCC_2013                   3221 non-null   int64
#  5   Description                 3221 non-null   object
#  6   orignal_population_2010_wa  39 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 176.3+ KB

# %%
pd.set_option('display.max_columns',7)

# %%
schema_df = pd.read_csv('/home/lizhi/projects/covid19/rural_urban_codes_2013.csv')

# %%
schema_df
# Out:
#        FIPS State          County_Name  Population_2010  RUCC_2013  \
# 0      1001    AL       Autauga County            54571          2
# 1      1003    AL       Baldwin County           182265          3
# 2      1005    AL       Barbour County            27457          6
# 3      1007    AL          Bibb County            22915          1
# 4      1009    AL        Blount County            57322          1
# ...     ...   ...                  ...              ...        ...
# 3216  72145    PR  Vega Baja Municipio            59662          1
# 3217  72147    PR    Vieques Municipio             9301          7
# 3218  72149    PR   Villalba Municipio            26073          2
# 3219  72151    PR    Yabucoa Municipio            37941          1
# 3220  72153    PR      Yauco Municipio            42043          2
#
#                                             Description  \
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# 2     Nonmetro - Urban population of 2,500 to 19,999...
# 3     Metro - Counties in metro areas of 1 million p...
# 4     Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3216  Metro - Counties in metro areas of 1 million p...
# 3217  Nonmetro - Urban population of 2,500 to 19,999...
# 3218  Metro - Counties in metro areas of 250,000 to ...
# 3219  Metro - Counties in metro areas of 1 million p...
# 3220  Metro - Counties in metro areas of 250,000 to ...
#
#       orignal_population_2010_wa
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3216                         NaN
# 3217                         NaN
# 3218                         NaN
# 3219                         NaN
# 3220                         NaN
#
# [3221 rows x 7 columns]

# %%
df.head(10)
# Out:
#    FIPS State      County_Name  Population_2010  RUCC_2013  \
# 0  1001    AL   Autauga County            54571          2
# 1  1003    AL   Baldwin County           182265          3
# 2  1005    AL   Barbour County            27457          6
# 3  1007    AL      Bibb County            22915          1
# 4  1009    AL    Blount County            57322          1
# 5  1011    AL   Bullock County            10914          6
# 6  1013    AL    Butler County            20947          6
# 7  1015    AL   Calhoun County           118572          3
# 8  1017    AL  Chambers County            34215          6
# 9  1019    AL  Cherokee County            25989          6
#
#                                          Description  \
# 0  Metro - Counties in metro areas of 250,000 to ...
# 1  Metro - Counties in metro areas of fewer than ...
# 2  Nonmetro - Urban population of 2,500 to 19,999...
# 3  Metro - Counties in metro areas of 1 million p...
# 4  Metro - Counties in metro areas of 1 million p...
# 5  Nonmetro - Urban population of 2,500 to 19,999...
# 6  Nonmetro - Urban population of 2,500 to 19,999...
# 7  Metro - Counties in metro areas of fewer than ...
# 8  Nonmetro - Urban population of 2,500 to 19,999...
# 9  Nonmetro - Urban population of 2,500 to 19,999...
#
#    orignal_population_2010_wa
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN

# %%
df.count()
# Out:
# FIPS                          3221
# State                         3221
# County_Name                   3221
# Population_2010               3221
# RUCC_2013                     3221
# Description                   3221
# orignal_population_2010_wa      39
# dtype: int64

# %%
df['FIPS']
# Out:
# 0        1001
# 1        1003
# 2        1005
# 3        1007
# 4        1009
#         ...
# 3216    72145
# 3217    72147
# 3218    72149
# 3219    72151
# 3220    72153
# Name: FIPS, Length: 3221, dtype: int64

# %%
df[['FIPS','County_Name']]
# Out:
#        FIPS          County_Name
# 0      1001       Autauga County
# 1      1003       Baldwin County
# 2      1005       Barbour County
# 3      1007          Bibb County
# 4      1009        Blount County
# ...     ...                  ...
# 3216  72145  Vega Baja Municipio
# 3217  72147    Vieques Municipio
# 3218  72149   Villalba Municipio
# 3219  72151    Yabucoa Municipio
# 3220  72153      Yauco Municipio
#
# [3221 rows x 2 columns]

# %%
type(df[['FIPS','County_Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['FIPS', 'State', 'County_Name', 'Population_2010', 'RUCC_2013',
#        'Description', 'orignal_population_2010_wa'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# FIPS                                                                       1001
# State                                                                        AL
# County_Name                                                      Autauga County
# Population_2010                                                           54571
# RUCC_2013                                                                     2
# Description                   Metro - Counties in metro areas of 250,000 to ...
# orignal_population_2010_wa                                                  NaN
# Name: 0, dtype: object

# %%
df.iloc[4]
# Out:
# FIPS                                                                       1009
# State                                                                        AL
# County_Name                                                       Blount County
# Population_2010                                                           57322
# RUCC_2013                                                                     1
# Description                   Metro - Counties in metro areas of 1 million p...
# orignal_population_2010_wa                                                  NaN
# Name: 4, dtype: object

# %%
df.iloc[2,5]
# Out:
# 'Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area                                                                                                                                '

# %%
df.iloc[[1,2]]
# Out:
#    FIPS State     County_Name  Population_2010  RUCC_2013  \
# 1  1003    AL  Baldwin County           182265          3
# 2  1005    AL  Barbour County            27457          6
#
#                                          Description  \
# 1  Metro - Counties in metro areas of fewer than ...
# 2  Nonmetro - Urban population of 2,500 to 19,999...
#
#    orignal_population_2010_wa
# 1                         NaN
# 2                         NaN

# %%
df.iloc[[1,2],5]
# Out:
# 1    Metro - Counties in metro areas of fewer than ...
# 2    Nonmetro - Urban population of 2,500 to 19,999...
# Name: Description, dtype: object

# %%
df.iloc[[1],[2,3,4,5]]
# Out:
#       County_Name  Population_2010  RUCC_2013  \
# 1  Baldwin County           182265          3
#
#                                          Description
# 1  Metro - Counties in metro areas of fewer than ...

# %%
df.loc[[2,5]]
# Out:
#    FIPS State     County_Name  Population_2010  RUCC_2013  \
# 2  1005    AL  Barbour County            27457          6
# 5  1011    AL  Bullock County            10914          6
#
#                                          Description  \
# 2  Nonmetro - Urban population of 2,500 to 19,999...
# 5  Nonmetro - Urban population of 2,500 to 19,999...
#
#    orignal_population_2010_wa
# 2                         NaN
# 5                         NaN

# %%
df.loc[[2,5],'Description']
# Out:
# 2    Nonmetro - Urban population of 2,500 to 19,999...
# 5    Nonmetro - Urban population of 2,500 to 19,999...
# Name: Description, dtype: object

# %%
df['State'].value_counts()
# Out:
# TX    254
# GA    159
# VA    134
# KY    120
# MO    115
# KS    105
# IL    102
# NC    100
# IA     99
# TN     95
# NE     93
# IN     92
# OH     88
# MN     87
# MI     83
# MS     82
# PR     78
# OK     77
# AR     75
# WI     72
# PA     67
# AL     67
# FL     67
# SD     66
# LA     64
# CO     64
# NY     62
# CA     58
# MT     56
# WV     55
# ND     53
# SC     46
# ID     44
# WA     39
# OR     36
# NM     33
# AK     29
# UT     29
# MD     24
# WY     23
# NJ     21
# NV     17
# ME     16
# AZ     15
# VT     14
# MA     14
# NH     10
# CT      8
# RI      5
# HI      5
# DE      3
# DC      1
# Name: State, dtype: int64

# %%
df.set_index('State')
# Out:
#         FIPS          County_Name  Population_2010  RUCC_2013  \
# State
# AL      1001       Autauga County            54571          2
# AL      1003       Baldwin County           182265          3
# AL      1005       Barbour County            27457          6
# AL      1007          Bibb County            22915          1
# AL      1009        Blount County            57322          1
# ...      ...                  ...              ...        ...
# PR     72145  Vega Baja Municipio            59662          1
# PR     72147    Vieques Municipio             9301          7
# PR     72149   Villalba Municipio            26073          2
# PR     72151    Yabucoa Municipio            37941          1
# PR     72153      Yauco Municipio            42043          2
#
#                                              Description  \
# State
# AL     Metro - Counties in metro areas of 250,000 to ...
# AL     Metro - Counties in metro areas of fewer than ...
# AL     Nonmetro - Urban population of 2,500 to 19,999...
# AL     Metro - Counties in metro areas of 1 million p...
# AL     Metro - Counties in metro areas of 1 million p...
# ...                                                  ...
# PR     Metro - Counties in metro areas of 1 million p...
# PR     Nonmetro - Urban population of 2,500 to 19,999...
# PR     Metro - Counties in metro areas of 250,000 to ...
# PR     Metro - Counties in metro areas of 1 million p...
# PR     Metro - Counties in metro areas of 250,000 to ...
#
#        orignal_population_2010_wa
# State
# AL                            NaN
# AL                            NaN
# AL                            NaN
# AL                            NaN
# AL                            NaN
# ...                           ...
# PR                            NaN
# PR                            NaN
# PR                            NaN
# PR                            NaN
# PR                            NaN
#
# [3221 rows x 6 columns]

# %%
df.sort_index(ascending=True )
# Out:
#        FIPS State          County_Name  Population_2010  RUCC_2013  \
# 0      1001    AL       Autauga County            54571          2
# 1      1003    AL       Baldwin County           182265          3
# 2      1005    AL       Barbour County            27457          6
# 3      1007    AL          Bibb County            22915          1
# 4      1009    AL        Blount County            57322          1
# ...     ...   ...                  ...              ...        ...
# 3216  72145    PR  Vega Baja Municipio            59662          1
# 3217  72147    PR    Vieques Municipio             9301          7
# 3218  72149    PR   Villalba Municipio            26073          2
# 3219  72151    PR    Yabucoa Municipio            37941          1
# 3220  72153    PR      Yauco Municipio            42043          2
#
#                                             Description  \
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# 2     Nonmetro - Urban population of 2,500 to 19,999...
# 3     Metro - Counties in metro areas of 1 million p...
# 4     Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3216  Metro - Counties in metro areas of 1 million p...
# 3217  Nonmetro - Urban population of 2,500 to 19,999...
# 3218  Metro - Counties in metro areas of 250,000 to ...
# 3219  Metro - Counties in metro areas of 1 million p...
# 3220  Metro - Counties in metro areas of 250,000 to ...
#
#       orignal_population_2010_wa
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3216                         NaN
# 3217                         NaN
# 3218                         NaN
# 3219                         NaN
# 3220                         NaN
#
# [3221 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3221, step=1)

# %%
filt = (df['State'] == 'WA')

# %%
df[filt]
# Out:
#        FIPS State          County_Name  Population_2010  RUCC_2013  \
# 2954  53001    WA         Adams County            18728          6
# 2955  53003    WA        Asotin County            21623          3
# 2956  53005    WA        Benton County           201800          2
# 2957  53007    WA        Chelan County            78420          3
# 2958  53009    WA       Clallam County            76010          5
# 2959  53011    WA         Clark County           488500          1
# 2960  53013    WA      Columbia County             4078          3
# 2961  53015    WA       Cowlitz County           108950          3
# 2962  53017    WA       Douglas County            42820          3
# 2963  53019    WA         Ferry County             7551          9
# 2964  53021    WA      Franklin County            94680          2
# 2965  53023    WA      Garfield County             2266          8
# 2966  53025    WA         Grant County            98740          5
# 2967  53027    WA  Grays Harbor County            74160          4
# 2968  53029    WA        Island County            84820          4
# 2969  53031    WA     Jefferson County            31900          6
# 2970  53033    WA          King County          2226300          1
# 2971  53035    WA        Kitsap County           270100          2
# 2972  53037    WA      Kittitas County            46570          4
# 2973  53039    WA     Klickitat County            22430          6
# 2974  53041    WA         Lewis County            79480          4
# 2975  53043    WA       Lincoln County            10570          8
# 2976  53045    WA         Mason County            64980          4
# 2977  53047    WA      Okanogan County            42730          6
# 2978  53049    WA       Pacific County            21640          7
# 2979  53051    WA  Pend Oreille County            13001          2
# 2980  53053    WA        Pierce County           888300          1
# 2981  53055    WA      San Juan County            17150          9
# 2982  53057    WA        Skagit County           129200          3
# 2983  53059    WA      Skamania County            11066          1
# 2984  53061    WA     Snohomish County           818700          1
# 2985  53063    WA       Spokane County           515250          2
# 2986  53065    WA       Stevens County            45570          2
# 2987  53067    WA      Thurston County           285800          2
# 2988  53069    WA     Wahkiakum County             4190          8
# 2989  53071    WA   Walla Walla County            62200          3
# 2990  53073    WA       Whatcom County           225300          3
# 2991  53075    WA       Whitman County            44776          4
# 2992  53077    WA        Yakima County           255950          3
#
#                                             Description  \
# 2954  Nonmetro - Urban population of 2,500 to 19,999...
# 2955  Metro - Counties in metro areas of fewer than ...
# 2956  Metro - Counties in metro areas of 250,000 to ...
# 2957  Metro - Counties in metro areas of fewer than ...
# 2958  Nonmetro - Urban population of 20,000 or more,...
# 2959  Metro - Counties in metro areas of 1 million p...
# 2960  Metro - Counties in metro areas of fewer than ...
# 2961  Metro - Counties in metro areas of fewer than ...
# 2962  Metro - Counties in metro areas of fewer than ...
# 2963  Nonmetro - Completely rural or less than 2,500...
# 2964  Metro - Counties in metro areas of 250,000 to ...
# 2965  Nonmetro - Completely rural or less than 2,500...
# 2966  Nonmetro - Urban population of 20,000 or more,...
# 2967  Nonmetro - Urban population of 20,000 or more,...
# 2968  Nonmetro - Urban population of 20,000 or more,...
# 2969  Nonmetro - Urban population of 2,500 to 19,999...
# 2970  Metro - Counties in metro areas of 1 million p...
# 2971  Metro - Counties in metro areas of 250,000 to ...
# 2972  Nonmetro - Urban population of 20,000 or more,...
# 2973  Nonmetro - Urban population of 2,500 to 19,999...
# 2974  Nonmetro - Urban population of 20,000 or more,...
# 2975  Nonmetro - Completely rural or less than 2,500...
# 2976  Nonmetro - Urban population of 20,000 or more,...
# 2977  Nonmetro - Urban population of 2,500 to 19,999...
# 2978  Nonmetro - Urban population of 2,500 to 19,999...
# 2979  Metro - Counties in metro areas of 250,000 to ...
# 2980  Metro - Counties in metro areas of 1 million p...
# 2981  Nonmetro - Completely rural or less than 2,500...
# 2982  Metro - Counties in metro areas of fewer than ...
# 2983  Metro - Counties in metro areas of 1 million p...
# 2984  Metro - Counties in metro areas of 1 million p...
# 2985  Metro - Counties in metro areas of 250,000 to ...
# 2986  Metro - Counties in metro areas of 250,000 to ...
# 2987  Metro - Counties in metro areas of 250,000 to ...
# 2988  Nonmetro - Completely rural or less than 2,500...
# 2989  Metro - Counties in metro areas of fewer than ...
# 2990  Metro - Counties in metro areas of fewer than ...
# 2991  Nonmetro - Urban population of 20,000 or more,...
# 2992  Metro - Counties in metro areas of fewer than ...
#
#       orignal_population_2010_wa
# 2954                     18728.0
# 2955                     21623.0
# 2956                    175177.0
# 2957                     72453.0
# 2958                     71404.0
# 2959                    425363.0
# 2960                      4078.0
# 2961                    102410.0
# 2962                     38431.0
# 2963                      7551.0
# 2964                     78163.0
# 2965                      2266.0
# 2966                     89120.0
# 2967                     72797.0
# 2968                     78506.0
# 2969                     29872.0
# 2970                   1931249.0
# 2971                    251133.0
# 2972                     40915.0
# 2973                     20318.0
# 2974                     75455.0
# 2975                     10570.0
# 2976                     60699.0
# 2977                     41120.0
# 2978                     20920.0
# 2979                     13001.0
# 2980                    795225.0
# 2981                     15769.0
# 2982                    116901.0
# 2983                     11066.0
# 2984                    713335.0
# 2985                    471221.0
# 2986                     43531.0
# 2987                    252264.0
# 2988                      3978.0
# 2989                     58781.0
# 2990                    201140.0
# 2991                     44776.0
# 2992                    243231.0

# %%
df.loc[filt,'Population_2010']
# Out:
# 2954      18728
# 2955      21623
# 2956     201800
# 2957      78420
# 2958      76010
# 2959     488500
# 2960       4078
# 2961     108950
# 2962      42820
# 2963       7551
# 2964      94680
# 2965       2266
# 2966      98740
# 2967      74160
# 2968      84820
# 2969      31900
# 2970    2226300
# 2971     270100
# 2972      46570
# 2973      22430
# 2974      79480
# 2975      10570
# 2976      64980
# 2977      42730
# 2978      21640
# 2979      13001
# 2980     888300
# 2981      17150
# 2982     129200
# 2983      11066
# 2984     818700
# 2985     515250
# 2986      45570
# 2987     285800
# 2988       4190
# 2989      62200
# 2990     225300
# 2991      44776
# 2992     255950
# Name: Population_2010, dtype: int64

# %%
df.loc[filt,'Population_2010']
# Out:
# 2954      18728
# 2955      21623
# 2956     201800
# 2957      78420
# 2958      76010
# 2959     488500
# 2960       4078
# 2961     108950
# 2962      42820
# 2963       7551
# 2964      94680
# 2965       2266
# 2966      98740
# 2967      74160
# 2968      84820
# 2969      31900
# 2970    2226300
# 2971     270100
# 2972      46570
# 2973      22430
# 2974      79480
# 2975      10570
# 2976      64980
# 2977      42730
# 2978      21640
# 2979      13001
# 2980     888300
# 2981      17150
# 2982     129200
# 2983      11066
# 2984     818700
# 2985     515250
# 2986      45570
# 2987     285800
# 2988       4190
# 2989      62200
# 2990     225300
# 2991      44776
# 2992     255950
# Name: Population_2010, dtype: int64

# %%
population_100k = df['Population_2010']>=100000

# %%
df.loc[filt & population_100k & df['RUCC_2013'] == 3]
# Out:
# Empty DataFrame
# Columns: [FIPS, State, County_Name, Population_2010, RUCC_2013, Description, orignal_population_2010_wa]
# Index: []

# %%
df.loc[population_100k]
# Out:
#        FIPS State         County_Name  Population_2010  RUCC_2013  \
# 1      1003    AL      Baldwin County           182265          3
# 7      1015    AL      Calhoun County           118572          3
# 27     1055    AL       Etowah County           104430          3
# 34     1069    AL      Houston County           101547          3
# 36     1073    AL    Jefferson County           658466          1
# ...     ...   ...                 ...              ...        ...
# 3153  72021    PR   Bayamon Municipio           208116          1
# 3155  72025    PR    Caguas Municipio           142893          1
# 3158  72031    PR  Carolina Municipio           176762          1
# 3200  72113    PR     Ponce Municipio           166327          2
# 3207  72127    PR  San Juan Municipio           395326          1
#
#                                             Description  \
# 1     Metro - Counties in metro areas of fewer than ...
# 7     Metro - Counties in metro areas of fewer than ...
# 27    Metro - Counties in metro areas of fewer than ...
# 34    Metro - Counties in metro areas of fewer than ...
# 36    Metro - Counties in metro areas of 1 million p...
# ...                                                 ...
# 3153  Metro - Counties in metro areas of 1 million p...
# 3155  Metro - Counties in metro areas of 1 million p...
# 3158  Metro - Counties in metro areas of 1 million p...
# 3200  Metro - Counties in metro areas of 250,000 to ...
# 3207  Metro - Counties in metro areas of 1 million p...
#
#       orignal_population_2010_wa
# 1                            NaN
# 7                            NaN
# 27                           NaN
# 34                           NaN
# 36                           NaN
# ...                          ...
# 3153                         NaN
# 3155                         NaN
# 3158                         NaN
# 3200                         NaN
# 3207                         NaN
#
# [583 rows x 7 columns]

# %%
df.loc[filt & population_100k]
# Out:
#        FIPS State       County_Name  Population_2010  RUCC_2013  \
# 2956  53005    WA     Benton County           201800          2
# 2959  53011    WA      Clark County           488500          1
# 2961  53015    WA    Cowlitz County           108950          3
# 2970  53033    WA       King County          2226300          1
# 2971  53035    WA     Kitsap County           270100          2
# 2980  53053    WA     Pierce County           888300          1
# 2982  53057    WA     Skagit County           129200          3
# 2984  53061    WA  Snohomish County           818700          1
# 2985  53063    WA    Spokane County           515250          2
# 2987  53067    WA   Thurston County           285800          2
# 2990  53073    WA    Whatcom County           225300          3
# 2992  53077    WA     Yakima County           255950          3
#
#                                             Description  \
# 2956  Metro - Counties in metro areas of 250,000 to ...
# 2959  Metro - Counties in metro areas of 1 million p...
# 2961  Metro - Counties in metro areas of fewer than ...
# 2970  Metro - Counties in metro areas of 1 million p...
# 2971  Metro - Counties in metro areas of 250,000 to ...
# 2980  Metro - Counties in metro areas of 1 million p...
# 2982  Metro - Counties in metro areas of fewer than ...
# 2984  Metro - Counties in metro areas of 1 million p...
# 2985  Metro - Counties in metro areas of 250,000 to ...
# 2987  Metro - Counties in metro areas of 250,000 to ...
# 2990  Metro - Counties in metro areas of fewer than ...
# 2992  Metro - Counties in metro areas of fewer than ...
#
#       orignal_population_2010_wa
# 2956                    175177.0
# 2959                    425363.0
# 2961                    102410.0
# 2970                   1931249.0
# 2971                    251133.0
# 2980                    795225.0
# 2982                    116901.0
# 2984                    713335.0
# 2985                    471221.0
# 2987                    252264.0
# 2990                    201140.0
# 2992                    243231.0

# %%
df.describe()
# Out:
#                FIPS  Population_2010    RUCC_2013  orignal_population_2010_wa
# count   3221.000000     3.221000e+03  3221.000000                3.900000e+01
# mean   31399.890407     9.726268e+04     4.936976                1.724241e+05
# std    16293.347468     3.100799e+05     2.724413                3.424514e+05
# min     1001.000000     8.200000e+01     1.000000                2.266000e+03
# 25%    19033.000000     1.131000e+04     2.000000                2.061900e+04
# 50%    30025.000000     2.607600e+04     6.000000                6.069900e+04
# 75%    46109.000000     6.588000e+04     7.000000                1.460390e+05
# max    72153.000000     9.818605e+06     9.000000                1.931249e+06

# %%
Trying to find if the legend label can be shared in multiple plots.
from bokeh.io import show
from bokeh.plotting import figure
from bokeh.models import LegendItem, Legend
from numpy.random import random, choice
from bokeh.layouts import gridplot
from webcolors import html4_names_to_hex

del html4_names_to_hex['white']
palette = list(html4_names_to_hex.keys())

fig_list = [figure(plot_width=300,plot_height=300) for i in range(4)]

renderer_list = []
color_list = []
for fig in fig_list:
    for i in range(5):
        color = choice(palette)
        renderer = fig.line(range(10),random(10),line_width=2,color=color)
        renderer_list += [renderer]
        color_list += [color]

# Lines with the same color will share a same legend item
legend_items = [LegendItem(label=color,renderers=[renderer for renderer in renderer_list if renderer.glyph.line_color==color]) for color in set(color_list)]

## Use a dummy figure for the LEGEND
dum_fig = figure(plot_width=300,plot_height=600,outline_line_alpha=0,toolbar_location=None)
# set the components of the figure invisible
for fig_component in [dum_fig.grid[0],dum_fig.ygrid[0],dum_fig.xaxis[0],dum_fig.yaxis[0]]:
    fig_component.visible = False
# The glyphs referred by the legend need to be present in the figure that holds the legend, so we must add them to the figure renderers
dum_fig.renderers += renderer_list
# set the figure range outside of the range of all glyphs
dum_fig.x_range.end = 1005
dum_fig.x_range.start = 1000
# add the legend
dum_fig.add_layout( Legend(click_policy='hide',location='top_left',border_line_alpha=0,items=legend_items) )

figrid = gridplot(fig_list,ncols=2,toolbar_location='left')
final = gridplot([[figrid,dum_fig]],toolbar_location=None)
show(final)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-53d3fc02ed35> in <module>
#       4 from numpy.random import random, choice
#       5 from bokeh.layouts import gridplot
# ----> 6 from webcolors import html4_names_to_hex
#       7
#       8 del html4_names_to_hex['white']
#
# ModuleNotFoundError: No module named 'webcolors'

# %%
import l_common as c
import itertools as it
import operator
import datetime

sql_str = """
    select date, state, county,
    cases-lag(cases, 1) over(partition by county order by date) as daily_cases,
    deaths-lag(deaths,1) over(partition by county order by date) as daily_deaths
    from covid19.us_counties
    where state in ('Washington', 'Alabama')
    and date > date_sub(current_date(), interval 1 MONTH)
    and lower(substr(county,1,1)) in ('a','k')
    order by state, county, date"""

col_names = ['date', 'state', 'county', 'daily_cases', 'daily_deaths']

df = c.dataframe_from_sql(col_names, sql_str)
# source = ColumnDataSource(df)

# c.all_counties_graph('Washington', df)
# c.all_counties_graph('Alabama', df)
c.list_of_state_graph(["Alabama", "Washington"], df)
